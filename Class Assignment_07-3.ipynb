# %% [markdown]
#   For Assignments Submission :
#   Sunday's assignment :
#
#   1. Use Functions to Create Addition, Subtraction, Multiplication & Division   Based Functions. (Dynamic Function)
#
#   2. Use Functions to Create a Calculator.
#
#   3. Do Research on How to Create Default Parameters & Its Use-Case.
#
#   Note:
#   Some Main Topics Covered So Far: (For Loop, While Loop, Functions, Dictionaries, List, Operators, Range Method, Data Types). Print Function, Installation (Python, VS Code).
#
#   How to Use Google Colab.

# %% [markdown]
# # 1. Assignment one :
# # 1. Addition, Subtraction, Multiplication & Division Functions (Dynamic Function)

# %%
def add(a, b):
    return a + b

def subtract(a, b):
    return a - b

def multiply(a, b):
    return a * b

def divide(a, b):
    if b != 0:
        return a / b
    else:
        return "Division By Zero is Not Allowed"
        print("Division By Zero is Not Allowed")

# %% [markdown]
# # 2. Assignment Two :
# # 2. Create A Calculator Using Functions
# #    Dynamic Function

# %%
def calculator():
    print("Choose an operation: +, -, *, /")
    operation = input("Enter operation: ")
    num1 = float(input("Enter first number: "))
    num2 = float(input("Enter second number: "))

    if operation == "+":
        print("Result:", add(num1, num2))
    elif operation == "-":
        print("Result:", subtract(num1, num2))
    elif operation == "*":
        print("Result:", multiply(num1, num2))
    elif operation == "/":
        print("Result:", divide(num1, num2))
    else:
        print("Invalid operation")

calculator()
# Out:
# Choose an operation: +, -, *, /
# Enter operation: *
# Enter first number: 2
# Enter second number: 55
# Result: 110.0

# %% [markdown]
# # 3. Assignment Three :
# # 3.Research on Default Parameters & Use-Case
#
# # 3. Assignment Three & Second Use-Case

# %%
def greet(name="Guest"):
    return f"Hello, {name}!"

# Use-Case:
print(greet())           # Default Parameter Will Be Used
print(greet("Ali"))      # Provided Parameter Will Overwrite Default
# Out:
# Hello, Guest!
# Hello, Ali!

# %%
def greet(name="Guest", times=11):
    for i in range(times):
        print(f"Perfect, {times}!")

# Using Default Parameters
greet()                # Default Name & Times
greet("Ali")           # Custom Name & Default Times
greet("Ali", 11)       # Custom Name & Custom Times
# Out:
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
# Perfect, 11!
