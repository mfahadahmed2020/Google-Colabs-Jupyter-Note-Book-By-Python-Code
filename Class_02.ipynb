# %% [markdown]
# Data Type = Name
#
# String = : str
#
# Integer = : int
#
# Boolean = True or False
#
# Numeric Data Type = Float 0.9, 45.5

# %%
name: str = "Sir Aneeq"
age: int = 20
is_active: bool = True
print(name)

name = "Sir Ameen"

print(name)

name: str = "M Fahad Ahmed"
age: int = "42"
price = 100.70
print(name)
print(age)
print(price)
price = 30 + 40
print(price)
# Out:
# Sir Aneeq
# Sir Ameen
# M Fahad Ahmed
# 42
# 100.7
# 70
